# %% [markdown]
# #CSV Column Manipulation

# %%
Here we are going to see , 
-selecting particular column
-Rename cloumn
-Delete Column
-Conditional operations on column

# %%
import pandas as pd

# %%
df = pd.read_csv('C:\Users\omc\Desktop\Machine-Learning-prerequisites\PopulationProjection2016.csv',index_col='State')

# %%
df.head()
# Out:
#                            Unnamed: 0    Male   Female      Total  Male .1  \
# State
# Andaman & Nicobar Islands           0    17547    17768     35315    11034
# Andhra Pradesh                      1  2165879  2032435   4198320  1309000
# Arunachal Pradesh                   2    88695    85828    174523    39439
# Assam                               3  1792270  1714270   3506540   944482
# Bihar                               4  7834139  7183699  15017838  3654434
#
#                            Female .1  Total.1
# State
# Andaman & Nicobar Islands      11198    22232
# Andhra Pradesh               1229445  2538440
# Arunachal Pradesh              38352    77791
# Assam                         894428  1838910
# Bihar                        3076180  6730614

# %%
df1 = df[['Female ','Male ']]

# %%
df1.head()
# Out:
#                            Female     Male
# State
# Andaman & Nicobar Islands    17768    17547
# Andhra Pradesh             2032435  2165879
# Arunachal Pradesh            85828    88695
# Assam                      1714270  1792270
# Bihar                      7183699  7834139

# %%
df1= df1.rename(columns={'Male ':'Male','Female ':'Female'})

# %%
df1.head()
# Out:
#                             Female     Male
# State
# Andaman & Nicobar Islands    17768    17547
# Andhra Pradesh             2032435  2165879
# Arunachal Pradesh            85828    88695
# Assam                      1714270  1792270
# Bihar                      7183699  7834139

# %%
df1= df1.rename(columns={'Male':'MALE','Female':'FEMALE'})

# %%
df1.head()
# Out:
#                             FEMALE     MALE
# State
# Andaman & Nicobar Islands    17768    17547
# Andhra Pradesh             2032435  2165879
# Arunachal Pradesh            85828    88695
# Assam                      1714270  1792270
# Bihar                      7183699  7834139

# %%
del df1['MALE']

# %%
df1.head()
# Out:
#                             FEMALE
# State
# Andaman & Nicobar Islands    17768
# Andhra Pradesh             2032435
# Arunachal Pradesh            85828
# Assam                      1714270
# Bihar                      7183699

# %%
df3= df [(df['Male '] > 88695)]

# %%
df3
# Out:
#                    Unnamed: 0     Male    Female      Total  Male .1  \
# State
# Andhra Pradesh              1   2165879   2032435   4198320  1309000
# Assam                       3   1792270   1714270   3506540   944482
# Bihar                       4   7834139   7183699  15017838  3654434
# Chhattisgarh                6   1426051   1366390   2792441   830310
# Delhi                       9    932351    772148   1704499   501072
# Gujarat                    11   3131580   2676818   5808398  1983836
# Haryana                    12   1417048   1139139   2556187   871900
# Himachal Pradesh           13    310230    277932    588162   187787
# Jammu and Kashmir          14    768343    684339   1452682   463187
# Jharkhand                  15   2094954   1982485   4077439  1053701
# Karnataka                  16   2708279   2541403   5249682  1642854
# Kerala                     17   1322468   1264005   2586473   836058
# ...
