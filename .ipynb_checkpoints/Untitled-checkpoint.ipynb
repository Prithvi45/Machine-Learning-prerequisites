# %% [markdown]
# #Reading and Writing into csv

# %%
import pandas as pd
from pandas import DataFrame
import datetime

# %%
df = pd.read_excel('C:\Users\omc\Desktop\Machine-Learning-prerequisites\PopulationProjection2016 updated.xlsx')

# %%
df.head()
# Out:
#                                    Projected Population in Different Age Group - 2016  \
# NaN     NaN                                                            All Categories
# Sl. No. States/\nUnion Territories                                         6-10 Years
# NaN     NaN                                                                     Male
# 1       2                                                                           3
#         Andaman & Nicobar Islands                                               17547
#
#                                    Unnamed: 1 Unnamed: 2   Unnamed: 3  \
# NaN     NaN                               NaN        NaN          NaN
# Sl. No. States/\nUnion Territories        NaN        NaN  11-13 Years
# NaN     NaN                           Female       Total        Male
# 1       2                                   4          5            6
#         Andaman & Nicobar Islands       17768      35315        11034
#
# ...

# %%
df.to_csv('C:\Users\omc\Desktop\Machine-Learning-prerequisites\PopulationProjection2016 updated.csv')

# %%
df_new = pd.read_csv('C:\Users\omc\Desktop\Machine-Learning-prerequisites\PopulationProjection2016 updated.csv')

# %%
df_new.head()
# Out:
#   Unnamed: 0                    Unnamed: 1  \
# 0        NaN                           NaN
# 1    Sl. No.  States/\r\nUnion Territories
# 2        NaN                           NaN
# 3          1                             2
# 4          1     Andaman & Nicobar Islands
#
#   Projected Population in Different Age Group - 2016 Unnamed: 1.1 Unnamed: 2  \
# 0                                     All Categories          NaN        NaN
# 1                                         6-10 Years          NaN        NaN
# 2                                              Male       Female       Total
# 3                                                  3            4          5
# 4                                              17547        17768      35315
#
#     Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 0          NaN        NaN        NaN
# 1  11-13 Years        NaN        NaN
# 2        Male     Female       Total
# 3            6          7          8
# 4        11034      11198      22232
#
# ...
